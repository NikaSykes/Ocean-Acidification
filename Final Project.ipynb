# %% [markdown]
# # Import

# %%
import numpy as np
import csv
import glob
import os

# %%
print(f)
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# <_io.TextIOWrapper name='pHMiamiFL.csv' mode='r' encoding='cp1252'>

# %% [markdown]
# # East Coast

# %%
#Import data file, skiprows and usecols will vary based on specific data file

f=open ('33GG20131114_BT.csv', 'r')
data = np.loadtxt('33GG20131114_BT.csv', comments="END_DATA", delimiter=",",skiprows=32, usecols=(29))
f.close()

#Remove -999 outliers

newdataX=[]
for x in range (0,len(data)):
    if ((data[x])>0):
                newdataX.append(data[x])

#Cacluate the average pH level             

avepH= (sum(newdataX))/ float(len(newdataX))

#Print average and range

print('pH average:',(avepH))
print('pH range:', ([min(newdataX),max(newdataX)]))

#Plot the pH levels on the y, with data reading along the x axis

Y = newdataX
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# pH average: 7.852351351351352
# pH range: [7.667, 8.065]
# Text(0, 0.5, 'pH ')

# %% [markdown]
# # West Coast

# %%
#Import data file

f=open ('WCOA11-01-06-2015_data.csv', 'r')
data = np.loadtxt('WCOA11-01-06-2015_data.csv', comments="END_DATA", delimiter=",",skiprows=1, usecols=(30))
f.close()

#To remove -999 outliers

newdataX=[]
for y in range (0,len(data)):
    if ((data[y])>0):
                newdataX.append(data[y])
                 
#Cacluate the average pH level 

avepH= sum(newdataX) / float(len(newdataX))

#Print average and range

print('pH average:',(avepH))
print('pH range:', ([min(newdataX),max(newdataX)]))

#Plot the pH levels on the y, with data reading along the x axis

Y = newdataX
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# pH average: 7.5637305825242676
# pH range: [7.218, 8.203]
# Text(0, 0.5, 'pH ')

# %% [markdown]
# # Hawaii

# %%
#Import data file

f=open ('Kewalo_data.csv', 'r')
data = np.loadtxt('Kewalo_data.csv', comments="END_DATA", delimiter=",", skiprows=13,  usecols=(6))
f.close()

#Remove -999 outliers

newdataX=[]
for y in range (0,len(data)):
    if ((data[y])>0):
                newdataX.append(data[y])
                 
#Cacluate the average pH level 

avepH= sum(newdataX) / float(len(newdataX))

#Print average and range

print('pH average:',(avepH))
print('pH range:', ([min(newdataX),max(newdataX)]))

#Plot the pH levels on the y, with data reading along the x axis

Y = newdataX
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# pH average: 8.058254810882506
# pH range: [7.91, 8.14]
# Text(0, 0.5, 'pH ')

# %% [markdown]
# # Bay of Bengal

# %%
#Import data file

f=open ('BOBOA_90E_15N_dp01_Nov2013_Dec2014.csv', 'r')
data = np.loadtxt('BOBOA_90E_15N_dp01_Nov2013_Dec2014.csv', comments="END_DATA", delimiter=",",skiprows=19, usecols=(24))
f.close()

#Remove -999 outliers

newdataX=[]
for y in range (0,len(data)):
    if ((data[y])>0):
                newdataX.append(data[y])
                 
#Cacluate the average pH level 

avepH= sum(newdataX) / float(len(newdataX))

#Print average and range

print('pH average:',(avepH))
print('pH range:', ([min(newdataX),max(newdataX)]))

#Plot the pH levels on the y, with data reading along the x axis

Y = newdataX
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# pH average: 8.050594680851058
# pH range: [7.9843, 8.1051]
# Text(0, 0.5, 'pH ')
