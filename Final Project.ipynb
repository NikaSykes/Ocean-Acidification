# %%
import numpy as np
import csv
import glob
import os

# %%
print(f)
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# <_io.TextIOWrapper name='phmiamiFL.csv' mode='r' encoding='cp1252'>

# %%
f=open ('phmiamiFL.csv', 'r')
data = np.loadtxt('phmiamiFL.csv', comments="END_DATA", delimiter=",",skiprows=32, usecols=(29))
f.close()
##print (data)

avepH= (sum(data)+(2*999)) / float(len(data))
print(avepH)

newdataX=[]
for x in range (0,len(data)):
    if ((data[x])>0):
                newdataX.append(data[x])
                 

Y = newdataX
A= avepH
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# 7.64571052631579
# Text(0, 0.5, 'pH ')

# %%
f=open ('phhawaiid.csv', 'r')
data = np.loadtxt('phhawaiid.csv', comments="END_DATA", delimiter=",", skiprows=13)
f.close()
##print (data)
avepH= sum(data) / float(len(data))
print(avepH)

print([min(data),max(data)])

Y = data
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# 8.048909090909097
# [7.97, 8.11]
# Text(0, 0.5, 'pH ')

# %%
f=open ('phBayofbengalindianocean.csv', 'r')
data = np.loadtxt('phBayofbengalindianocean.csv', comments="END_DATA", delimiter=",",skiprows=19, usecols=(24))
f.close()
##print (data)
newdataX=[]


for y in range (0,len(data)):
    if ((data[y])>0):
                newdataX.append(data[y])
                 

avepH= sum(newdataX) / float(len(newdataX))
print(avepH)

print([min(newdataX),max(newdataX)])

Y = newdataX
plt.plot(Y)
plt.xlabel('Data Reading')
plt.ylabel('pH ')
# Out:
# 8.050594680851058
# [7.9843, 8.1051]
# Text(0, 0.5, 'pH ')
